# %%
# EXCEPTION HANDLING IN PYTHON - Youtube

y = 10
print(y/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-ae03706e150d> in <module>()
#       2
#       3 y = 10
# ----> 4 print(y/0)
#
# ZeroDivisionError: division by zero

# %%
x = 10
if x > 5:
  raise Exception ('x should not exceed 5. The value of x was : {}'.format(x))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-19c9dc307f8e> in <module>()
#       1 x = 10
#       2 if x > 5:
# ----> 3   raise Exception ('x should not exceed 5. The value of x was : {}'.format(x))
#
# Exception: x should not exceed 5. The value of x was : 10

# %%
# AssertionError Exception

import sys
assert ('linux' in sys.platform), "This code run on Linux only"

# %%
def linux_interaction():
  assert ('linux' in sys.platform), "Function can run on Linux system"
  print('Doing something')

try:
  linux_interaction
except:
  print('Linux function was not executed')

# %%
try:
  linux_interaction
except AssertionError as error:
  print(error)
  print('The linux_interaction() was not executed')

# %%
try:
  with open('file.log') as file:
    read_data = file.read()
except:
  print('Could not open file.log')
# Out:
# Could not open file.log

# %%
try:
  with open('file.log') as file:
    read_data = file.read()
except FileNotFoundError as fnf_error:
  print(fnf_error)
# Out:
# [Errno 2] No such file or directory: 'file.log'

# %%
try:
  linux_interaction
  with open('file.log') as file:
    read_data = file.read()

except FileNotFoundError as fnf_error:
  print(fnf_error)

except AssertionError as error:
  print(error)
  print('Linux linux_interaction() function was not executed')
# Out:
# [Errno 2] No such file or directory: 'file.log'

# %%
try:
  linux_interaction

except AssertionError as error:
  print(error)
  
else:
  print('Executing the else clause')
# Out:
# Executing the else clause

# %%
try:
  linux_interaction

except AssertionError as error:
  print(error)

else:
  try:
    with open('file.log') as file:
      read_data = file.read()
  except FileNotFoundError as fnf_error:
      print(fnf_error)
# Out:
# [Errno 2] No such file or directory: 'file.log'

# %%
# The finally clause

try:
  linux_interaction

except AssertionError as error:
  print(error)

else:
  try:
    with open('file.log') as file:
      read_data = file.read()
  except FileNotFoundError as fnf_error:
      print(fnf_error)

finally:
  print('Cleaning up, irrespective of any exceptions.')
# Out:
# [Errno 2] No such file or directory: 'file.log'
# Cleaning up, irrespective of any exceptions.
